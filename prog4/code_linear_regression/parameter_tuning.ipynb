# %%
import numpy as np
from numpy.random import rand as rand
from numpy.random import seed as seed
import matplotlib.pyplot as plt
from IPython.display import clear_output
import linear_regression as LR
from misc.utils import MyUtils
import math
import sys
import pandas as pd

# %%
# import housing data
df_X_train = pd.read_csv('houseprice/x_train.csv', header=None)
df_y_train = pd.read_csv('houseprice/y_train.csv', header=None)
df_X_test = pd.read_csv('houseprice/x_test.csv', header=None)
df_y_test = pd.read_csv('houseprice/y_test.csv', header=None)

X_train = df_X_train.to_numpy()
X_test = df_X_test.to_numpy()
n_train = X_train.shape[0]

X_all = MyUtils.normalize_0_1(np.concatenate((X_train, X_test), axis=0))
X_train = X_all[:n_train]
X_test = X_all[n_train:]

y_train = df_y_train.to_numpy()
y_test = df_y_test.to_numpy()


print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (404, 1)
# (102, 13)
# (102, 1)

# %%
# Closed form parameter tuning
# Will tune params in the following order
# 1) degree space = 1
    # a. lambda vals
# 2) degree space = 2
    # a. lambda vals
# 3) degree space = 3
    # a. lambda vals
# 4) degree space = 4
    # a. lambda vals

# %%
# degree space = 1
error_arr1 = np.zeros(201)
error_arr2 = np.zeros(201)
lam_arr = np.arange(0, 2.01, 0.01)
z_r = 1
lr = LR.LinearRegression()

for i in range(201):

    # get new w vector with new lam value  
    lr.fit(X_train, y_train, CF = True, lam = i/100, eta = 0.01, epochs = 1000000, degree = z_r)
    
    error_arr1[i] = lr.error(X_train, y_train)
    error_arr2[i] = lr.error(X_test, y_test)

#print(lam_arr)
#print(error_arr)
    
plt.plot(lam_arr, error_arr1, label = "In-sample error")
plt.plot(lam_arr, error_arr2, label = "Out-of-sample error")
plt.xlabel('Lambda Values')
plt.ylabel('Error')
plt.title('Lambda Values vs Error')
plt.xlim(-0.01, 2)
#plt.ylim(1, 25)
plt.legend()
plt.show()

# %%
# degree space = 2
error_arr1 = np.zeros(201)
error_arr2 = np.zeros(201)
lam_arr = np.arange(0, 2.01, 0.01)
z_r = 2
lr = LR.LinearRegression()

for i in range(201):

    # get new w vector with new lam value  
    lr.fit(X_train, y_train, CF = True, lam = i/100, eta = 0.01, epochs = 1000000, degree = z_r)
    
    error_arr1[i] = lr.error(X_train, y_train)
    error_arr2[i] = lr.error(X_test, y_test)

#print(lam_arr)
#print(error_arr)
    
plt.plot(lam_arr, error_arr1, label = "In-sample error")
plt.plot(lam_arr, error_arr2, label = "Out-of-sample error")
plt.xlabel('Lambda Values')
plt.ylabel('Error')
plt.title('Lambda Values vs Error')
plt.xlim(-0.01, 2)
#plt.ylim(5, 20)
plt.legend()
plt.show()

# %%
# degree space = 3
error_arr1 = np.zeros(201)
error_arr2 = np.zeros(201)
lam_arr = np.arange(0, 2.01, 0.01)
z_r = 3
lr = LR.LinearRegression()

for i in range(201):

    # get new w vector with new lam value  
    lr.fit(X_train, y_train, CF = True, lam = i/100, eta = 0.01, epochs = 1000000, degree = z_r)
    
    error_arr1[i] = lr.error(X_train, y_train)
    error_arr2[i] = lr.error(X_test, y_test)

#print(lam_arr)
#print(error_arr)
    
plt.plot(lam_arr, error_arr1, label = "In-sample error")
plt.plot(lam_arr, error_arr2, label = "Out-of-sample error")
plt.xlabel('Lambda Values')
plt.ylabel('Error')
plt.title('Lambda Values vs Error')
plt.xlim(0, 0.3)
plt.ylim(0, 50)
plt.legend()
plt.show()

# %%
# degree space = 4
error_arr1 = np.zeros(201)
error_arr2 = np.zeros(201)
lam_arr = np.arange(0, 2.01, 0.01)
z_r = 4
lr = LR.LinearRegression()

for i in range(201):

    # get new w vector with new lam value  
    lr.fit(X_train, y_train, CF = True, lam = i/100, eta = 0.01, epochs = 1000000, degree = z_r)
    
    error_arr1[i] = lr.error(X_train, y_train)
    error_arr2[i] = lr.error(X_test, y_test)

#print(lam_arr)
#print(error_arr)
    
plt.plot(lam_arr, error_arr1, label = "In-sample error")
plt.plot(lam_arr, error_arr2, label = "Out-of-sample error")
plt.xlabel('Lambda Values')
plt.ylabel('Error')
plt.title('Lambda Values vs Error')
#plt.xlim(0, 0.3)
#plt.ylim(0, 50)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 11
#       6 lr = LR.LinearRegression()
#       8 for i in range(201):
#       9
#      10     # get new w vector with new lam value
# ---> 11     lr.fit(X_train, y_train, CF = True, lam = i/100, eta = 0.01, epochs = 1000000, degree = z_r)
#      13     error_arr1[i] = lr.error(X_train, y_train)
#      14     error_arr2[i] = lr.error(X_test, y_test)
#
# File ~/Documents/GitHub/cscd484/prog4/code_linear_regression/linear_regression.py:39, in LinearRegression.fit(self, X, y, CF, lam, eta, epochs, degree)
#      36 X = MyUtils.z_transform(X, degree = self.degree)
#      38 if CF:
# ---> 39     self._fit_cf(X, y, lam)
#      40 else:
#      41     self._fit_gd(X, y, lam, eta, epochs)
#
# File ~/Documents/GitHub/cscd484/prog4/code_linear_regression/linear_regression.py:62, in LinearRegression._fit_cf(self, X, y, lam)
#      59 X = np.insert(X, 0, np.ones(X.shape[0]), axis = 1)
#      60 self.w = np.zeros(d+1).reshape((d+1,1))
# ---> 62 self.w = np.linalg.pinv(X.T @ X + lam*np.identity(d+1)) @ X.T @ y
#      64 return self.w
#
# File <__array_function__ internals>:200, in pinv(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:1983, in pinv(a, rcond, hermitian)
#    1981     return wrap(res)
#    1982 a = a.conjugate()
# -> 1983 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    1985 # discard small singular values
#    1986 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File <__array_function__ internals>:200, in svd(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:1642, in svd(a, full_matrices, compute_uv, hermitian)
#    1639         gufunc = _umath_linalg.svd_n_s
#    1641 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1642 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1643 u = u.astype(result_t, copy=False)
#    1644 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
# Gradient descent parameter tuning
# Will tune params in the following order
# 1) degree space = 1
    # a. lambda vals
    # b. eta 
    # c. epochs
# 2) degree space = 2
    # a. lambda vals
    # b. eta 
    # c. epochs
# 3) degree space = 3
    # a. lambda vals
    # b. eta 
    # c. epochs
# 4) degree space = 4
    # a. lambda vals
    # b. eta 
    # c. epochs

# %%
# 1a -> lambda vals

error_arr1 = np.zeros(201)
error_arr2 = np.zeros(201)
lam_arr = np.arange(0, 2.01, 0.01)
z_r = 1
lr = LR.LinearRegression()

for i in range(201):

    # get new w vector with new lam value  
    # holding degree space, eta, and epochs constant 
    # with degree space = 1, eta = 0.01, epochs = 100000
    lr.fit(X_train, y_train, CF = False, lam = i/100, eta = 0.01, epochs = 100000, degree = z_r)
    
    error_arr1[i] = lr.error(X_train, y_train)
    error_arr2[i] = lr.error(X_test, y_test)

#print(lam_arr)
#print(error_arr)
    
plt.plot(lam_arr, error_arr1, label = "In-sample error")
plt.plot(lam_arr, error_arr2, label = "Out-of-sample error")
plt.xlabel('Lambda Values')
plt.ylabel('Error')
plt.title('Lambda Values vs Error')
#plt.xlim(0, 0.3)
#plt.ylim(0, 50)
plt.legend()
plt.show()

# %%
#### CURRENTLY BROKEN ####
# 1b -> eta 

error_arr1 = np.zeros(1001)
error_arr2 = np.zeros(1001)
eta_arr = np.arange(0, 1.001, 0.001)
z_r = 1
lr = LR.LinearRegression()

for i in range(1001):

    # get new w vector with new eta value  
    # holding degree space, eta, and lambda constant 
    # with degree space = 1, lam = 0.1, epochs = 100000
    lr.fit(X_train, y_train, CF = False, lam = 0.1, eta = i/1000, epochs = 100000, degree = z_r)
    
    error_arr1[i] = lr.error(X_train, y_train)
    error_arr2[i] = lr.error(X_test, y_test)

#print(lam_arr)
#print(error_arr)

print(error_arr1)
print(error_arr2)
plt.plot(eta_arr, error_arr1, label = "In-sample error")
plt.plot(eta_arr, error_arr2, label = "Out-of-sample error")
plt.xlabel('Eta Values')
plt.ylabel('Error')
plt.title('Eta Values vs Error')
plt.xlim(0, 0.1)
#plt.ylim(0, 50)
plt.legend()
plt.show()
# Out:
# [586.16049505  22.79301698  22.19591956 ...          nan          nan
#           nan]
# [615.85784314  21.93963177  22.30881401 ...          nan          nan
#           nan]

# %%
# 1c ->  epochs

error_arr1 = np.zeros(101)
error_arr2 = np.zeros(101)
epoch_arr = np.arange(0, 1000001, 10000)
z_r = 1
lr = LR.LinearRegression()

for i in range(0, 101):

    # get new w vector with new epochs 
    # holding degree space, eta, and lambda constant 
    # with degree space = 1, eta = 0.01, lam = 0.1
    lr.fit(X_train, y_train, CF = False, lam = 0.1, eta = 0.01, epochs = i*10000, degree = z_r)
    
    error_arr1[i] = lr.error(X_train, y_train)
    error_arr2[i] = lr.error(X_test, y_test)

#print(lam_arr)
#print(error_arr)
    
print(error_arr1)
print(error_arr2)
plt.plot(epoch_arr, error_arr1, label = "In-sample error")
plt.plot(epoch_arr, error_arr2, label = "Out-of-sample error")
plt.xlabel('Epoch Values')
plt.ylabel('Error')
plt.title('Epoch Values vs Error')
#plt.xlim(0, 0.3)
plt.ylim(20, 30)
plt.legend()
plt.show();
# Out:
# [586.16049505  22.7929583   22.19590281  22.0698085   22.03658802
#   22.02610403  22.02228658  22.0207622   22.02012192  22.01984614
#   22.01972592  22.01967321  22.01965003  22.01963984  22.01963534
#   22.01963336  22.01963249  22.01963211  22.01963194  22.01963186
#   22.01963183  22.01963181  22.01963181  22.01963181  22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318   22.0196318   22.0196318   22.0196318   22.0196318
#   22.0196318 ]
# [615.85784314  21.93961078  22.30884117  22.62890366  22.79211089
#   22.86775649  22.90172828  22.91680233  22.92345992  22.92639528
#   22.92768879  22.92825875  22.92850991  22.92862059  22.92866937
#   22.92869087  22.92870035  22.92870453  22.92870637  22.92870718
#   22.92870754  22.9287077   22.92870777  22.9287078   22.92870781
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782  22.92870782  22.92870782  22.92870782  22.92870782
#   22.92870782]
