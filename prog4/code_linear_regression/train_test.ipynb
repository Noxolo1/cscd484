# %%
import numpy as np
from numpy.random import rand as rand
from numpy.random import seed as seed
import matplotlib.pyplot as plt
from IPython.display import clear_output
import linear_regression as LR
from misc.utils import MyUtils
import math
import sys
import pandas as pd

# %%
# import housing data
df_X_train = pd.read_csv('houseprice/x_train.csv', header=None)
df_y_train = pd.read_csv('houseprice/y_train.csv', header=None)
df_X_test = pd.read_csv('houseprice/x_test.csv', header=None)
df_y_test = pd.read_csv('houseprice/y_test.csv', header=None)

X_train = df_X_train.to_numpy()
X_test = df_X_test.to_numpy()
n_train = X_train.shape[0]

X_all = MyUtils.normalize_0_1(np.concatenate((X_train, X_test), axis=0))
X_train = X_all[:n_train]
X_test = X_all[n_train:]

y_train = df_y_train.to_numpy()
y_test = df_y_test.to_numpy()


print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (404, 1)
# (102, 13)
# (102, 1)

# %%
# degree space
z_r = 3

lr = LR.LinearRegression()
lr.fit(X_train, y_train, CF = True, lam = 0.1, eta = 0.01, epochs = 1000000, degree = z_r)
print(lr.w.shape)
# Out:
# (560, 1)

# %%
# first for closed form LR
# need to create an array of errors to plot at different Z spaces and lambda values 
# tune params for z space first
# pick 1 z space, then iterate lambda values 
# degree space = 1

error_arr1 = np.zeros(101)
error_arr2 = np.zeros(101)
lam_arr = np.arange(0, 1.01, 0.01)

z_r = 1
lr = LR.LinearRegression()

for i in range(101):

    lr.fit(X_train, y_train, CF = True, lam = i/100, eta = 0.01, epochs = 1000000, degree = z_r)
    error_arr1[i] = lr.error(X_train, y_train)
    error_arr2[i] = lr.error(X_test, y_test)

#print(lam_arr)
#print(error_arr)
    
plt.plot(lam_arr, error_arr1)
plt.plot(lam_arr, error_arr2)
plt.xlabel('Lambda Values')
plt.ylabel('Error')
plt.title('Error vs Lambda Values')
plt.show()

# %%
# degree space = 2

error_arr = np.zeros(101)
lam_arr = np.arange(0, 1.01, 0.01)

z_r = 2
lr = LR.LinearRegression()

for i in range(101):

    lr.fit(X_train, y_train, CF = True, lam = i/100, eta = 0.01, epochs = 1000000, degree = z_r)
    error_arr[i] = lr.error(X_train, y_train)

#print(lam_arr)
#print(error_arr)
    
plt.plot(lam_arr, error_arr)
plt.xlabel('Lambda Values')
plt.ylabel('Error')
plt.title('Error vs Lambda Values')
plt.show()

# %%
# degree space = 3

error_arr = np.zeros(101)
lam_arr = np.arange(0, 1.01, 0.01)

z_r = 3
lr = LR.LinearRegression()

for i in range(101):

    lr.fit(X_train, y_train, CF = True, lam = i/100, eta = 0.01, epochs = 1000000, degree = z_r)
    error_arr[i] = lr.error(X_train, y_train)

#print(lam_arr)
#print(error_arr)
    
plt.plot(lam_arr, error_arr)
plt.xlabel('Lambda Values')
plt.ylabel('Error')
plt.title('Error vs Lambda Values')
plt.show()
